# %% [markdown]
# #### Start Notes

# %% [markdown]
# https://huggingface.co/blog/catherinearnett/hf-model-survey
# Huge disproportion of resources for some languages, some of which have a huge amount of speakers but no resources.
